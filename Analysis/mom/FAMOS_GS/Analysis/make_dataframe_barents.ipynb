# %%
# %matplotlib notebook
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import seaborn as sns
import colorlover as cl

py.offline.init_notebook_mode(connected=True)
# Out:
# matplotlib data path /home/milicak/anaconda2/lib/python2.7/site-packages/matplotlib/mpl-data
# loaded rc file /home/milicak/.config/matplotlib/matplotlibrc
# matplotlib version 2.1.2
# verbose.level helpful
# interactive is False
# platform is linux2
# $HOME=/home/milicak
# CACHEDIR=/home/milicak/.cache/matplotlib
# Using fontManager instance from /home/milicak/.cache/matplotlib/fontList.json
# backend nbAgg version unknown
# backend nbAgg version unknown
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
fname0 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/ITU-MOM/ITU-MOM_GSexps_1980_2009.nc'
ds0 = xr.open_mfdataset(fname0)

fname1 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/MITB500/MIT_MITB500_1980_2009.nc'
ds1 = xr.open_mfdataset(fname1)

fname2 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/Brest/Brest_GSexps_1980_2009.nc'
ds2 = xr.open_mfdataset(fname2)

fname3 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/NorESM/NorESM_GS_experiments_1980_2009.nc'
ds3 = xr.open_mfdataset(fname3)

fname4 = '../../../../../Analysis/mom/FAMOS_GS/Analysis/data/FESOM/FESOM_GS_exps_1980_2009.nc'
ds4 = xr.open_mfdataset(fname4)

# %%
dates0 = pd.date_range('1980-01', freq='M', periods=12*29)
ds0['time'] = dates0
ds1['time'] = dates0
ds2['time'] = dates0
ds3['time'] = dates0
ds4['time'] = dates0

# %%
""" Plot annual volume vs heat anomaly"""
modelnames = ['ITU' , 'MITB500', 'Brest', 'NorESM', 'FESOM']
data = {}

ctln = ['ctlbarents_volumeinflow', 'barvt_c[1]', 'BSOrefvolume_in', 'inflow_vt_NorESM_BSO_ctrl', 'ctlvoltransp_BSO_in']
gspn = ['gspbarents_volumeinflow', 'barvt_gsp[1]', 'BSOgspvolume_in', 'inflow_vt_NorESM_BSO_gsp', 'gspvoltransp_BSO_in']
gsnn = ['gsnbarents_volumeinflow', 'barvt_gsm[1]', 'BSOgsnvolume_in', 'inflow_vt_NorESM_BSO_gsn', 'gsnvoltransp_BSO_in']

varnames = ['gspvolumeinflow', 'gsnvolumeinflow']
coeffs = [1, 1e-6, 1, 1, 1]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean().year'
    time = np.copy(eval(dnm))
    data.update({'time': time})
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})
    

ctlhn = ['ctlbarents_heatinflow', 'barht_c[1]', 'BSOrefheat_in', 'inflow_ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO_in']
gsphn = ['gspbarents_heatinflow', 'barht_gsp[1]', 'BSOgspheat_in', 'inflow_ht_NorESM_BSO_gsp', 'gspheattransp_BSO_in']
gsnhn = ['gsnbarents_heatinflow', 'barht_gsm[1]', 'BSOgsnheat_in', 'inflow_ht_NorESM_BSO_gsn', 'gsnheattransp_BSO_in']

varnames = ['gspheatinflow', 'gsnheatinflow']
coeffs = [1, 1, 1, 1, 1]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})
    

ctlhn = ['ctlbarents_heattotal', 'barht_c[0]', 'BSOrefheat', 'ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO']
gsphn = ['gspbarents_heattotal', 'barht_gsp[0]', 'BSOgspheat', 'ht_NorESM_BSO_gsp', 'gspheattransp_BSO']
gsnhn = ['gsnbarents_heattotal', 'barht_gsm[0]', 'BSOgsnheat', 'ht_NorESM_BSO_gsn', 'gsnheattransp_BSO']
    
varnames = ['gspheattotal', 'gsnheattotal']
coeffs = [1, 1, 1, 1, 1]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})    
    
    
ctln = ['ctlbarents_volumetotal', 'barvt_c[0]', 'BSOrefvolume', 'vt_NorESM_BSO_ctrl', 'ctlvoltransp_BSO']
gspn = ['gspbarents_volumetotal', 'barvt_gsp[0]', 'BSOgspvolume', 'vt_NorESM_BSO_gsp', 'gspvoltransp_BSO']
gsnn = ['gsnbarents_volumetotal', 'barvt_gsm[0]', 'BSOgsnvolume', 'vt_NorESM_BSO_gsn', 'gsnvoltransp_BSO']
    
varnames = ['gspvolumetotal', 'gsnvolumetotal']
coeffs = [1, 1e-6, 1, 1, 1]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})     
    
    
ctln = ['ctlxice_barents', 'SIextBK_c', 'refice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_ctrl', 'ctliext_BK']
gspn = ['gspxice_barents', 'SIextBK_gsp', 'gspice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsp', 'gspiext_BK']
gsnn = ['gsnxice_barents', 'SIextBK_gsm', 'gsnice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsn', 'gsniext_BK']
    
varnames = ['gspiceextBS', 'gsniceextBS']
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})     
    

ctln = ['ctlxice', 'SIext_c', 'refice_extent_NH', 'ice_extent_NorESM_NH_ctrl', 'ctliext']
gspn = ['gspxice', 'SIext_gsp', 'gspice_extent_NH', 'ice_extent_NorESM_NH_gsp', 'gspiext']
gsnn = ['gsnxice', 'SIext_gsm', 'gsnice_extent_NH', 'ice_extent_NorESM_NH_gsn', 'gsniext']
    
varnames = ['gspiceextNH', 'gsniceextNH']
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})     
    
    
ctln = ['ctlvice_barents', 'SIvolBK_c', 'refice_volume_BSKS', 'ice_volume_NorESM_BarentsKara_ctrl', 'ctlivol_BK']
gspn = ['gspvice_barents', 'SIvolBK_gsp', 'gspice_volume_BSKS', 'ice_volume_NorESM_BarentsKara_gsp', 'gspivol_BK']
gsnn = ['gsnvice_barents', 'SIvolBK_gsm', 'gsnice_volume_BSKS', 'ice_volume_NorESM_BarentsKara_gsn', 'gsnivol_BK']
    
varnames = ['gspicevolBS', 'gsnicevolBS']
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})     
    

ctln = ['ctlvice', 'SIvol_c', 'refice_volume_NH', 'ice_volume_NorESM_NH_ctrl', 'ctlivol']
gspn = ['gspvice', 'SIvol_gsp', 'gspice_volume_NH', 'ice_volume_NorESM_NH_gsp', 'gspivol']
gsnn = ['gsnvice', 'SIvol_gsm', 'gsnice_volume_NH', 'ice_volume_NorESM_NH_gsn', 'gsnivol']
    
varnames = ['gspicevolNH', 'gsnicevolNH']
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]

for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    dnm = mdl+varnames[0]
    print dnm
    data.update({dnm: val1})
    dnm = mdl+varnames[1]
    print dnm
    data.update({dnm: val1})     
    

df = pd.DataFrame(data=data)    
df.to_csv('models_BSO_GSexps.csv')
# Out:
# ITUgspvolumeinflow
# ITUgsnvolumeinflow
# MITB500gspvolumeinflow
# MITB500gsnvolumeinflow
# Brestgspvolumeinflow
# Brestgsnvolumeinflow
# NorESMgspvolumeinflow
# NorESMgsnvolumeinflow
# FESOMgspvolumeinflow
# FESOMgsnvolumeinflow
# ITUgspheatinflow
# ITUgsnheatinflow
# MITB500gspheatinflow
# MITB500gsnheatinflow
# Brestgspheatinflow
# Brestgsnheatinflow
# NorESMgspheatinflow
# NorESMgsnheatinflow
# FESOMgspheatinflow
# FESOMgsnheatinflow
# ITUgspheattotal
# ITUgsnheattotal
# MITB500gspheattotal
# MITB500gsnheattotal
# Brestgspheattotal
# Brestgsnheattotal
# NorESMgspheattotal
# NorESMgsnheattotal
# FESOMgspheattotal
# FESOMgsnheattotal
# ITUgspvolumetotal
# ITUgsnvolumetotal
# MITB500gspvolumetotal
# MITB500gsnvolumetotal
# Brestgspvolumetotal
# Brestgsnvolumetotal
# NorESMgspvolumetotal
# NorESMgsnvolumetotal
# FESOMgspvolumetotal
# FESOMgsnvolumetotal
# ITUgspiceextBS
# ITUgsniceextBS
# MITB500gspiceextBS
# MITB500gsniceextBS
# BrestgspiceextBS
# BrestgsniceextBS
# NorESMgspiceextBS
# NorESMgsniceextBS
# FESOMgspiceextBS
# FESOMgsniceextBS
# ITUgspiceextNH
# ITUgsniceextNH
# MITB500gspiceextNH
# MITB500gsniceextNH
# BrestgspiceextNH
# BrestgsniceextNH
# NorESMgspiceextNH
# NorESMgsniceextNH
# FESOMgspiceextNH
# FESOMgsniceextNH
# ITUgspicevolBS
# ITUgsnicevolBS
# MITB500gspicevolBS
# MITB500gsnicevolBS
# BrestgspicevolBS
# BrestgsnicevolBS
# NorESMgspicevolBS
# NorESMgsnicevolBS
# FESOMgspicevolBS
# FESOMgsnicevolBS
# ITUgspicevolNH
# ITUgsnicevolNH
# MITB500gspicevolNH
# MITB500gsnicevolNH
# BrestgspicevolNH
# BrestgsnicevolNH
# NorESMgspicevolNH
# NorESMgsnicevolNH
# FESOMgspicevolNH
# FESOMgsnicevolNH

# %%
""" Plot annual volume vs heat anomaly"""
modelnames = ['ITU' , 'MITB500', 'Brest', 'NorESM', 'FESOM']

ctln = ['ctlbarents_volumetotal', 'barvt_c[0]', 'BSOrefvolume', 'vt_NorESM_BSO_ctrl', 'ctlvoltransp_BSO']
gspn = ['gspbarents_volumetotal', 'barvt_gsp[0]', 'BSOgspvolume', 'vt_NorESM_BSO_gsp', 'gspvoltransp_BSO']
gsnn = ['gsnbarents_volumetotal', 'barvt_gsm[0]', 'BSOgsnvolume', 'vt_NorESM_BSO_gsn', 'gsnvoltransp_BSO']
    
coeffs = [1, 1e-6, 1, 1, 1]

timelen = 29;
time = []
voltr = []
voltrin = []
heattr = []
heattrin = []
seaiceextBS = []
seaiceextNH = []
seaicevolBS = []
seaicevolNH = []
direction = []
models = []
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean().year'
    time = np.append(time,np.copy(eval(dnm)))
    time = np.append(time,np.copy(eval(dnm)))
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    voltr = np.append(voltr,val1)
    direction = np.append(direction,1*np.ones(timelen))    
    voltr = np.append(voltr,val2)
    direction = np.append(direction,-1*np.ones(timelen))
    for ind2 in xrange(2*timelen):
        models.append(mdl)
        

ctln = ['ctlbarents_volumeinflow', 'barvt_c[1]', 'BSOrefvolume_in', 'inflow_vt_NorESM_BSO_ctrl', 'ctlvoltransp_BSO_in']
gspn = ['gspbarents_volumeinflow', 'barvt_gsp[1]', 'BSOgspvolume_in', 'inflow_vt_NorESM_BSO_gsp', 'gspvoltransp_BSO_in']
gsnn = ['gsnbarents_volumeinflow', 'barvt_gsm[1]', 'BSOgsnvolume_in', 'inflow_vt_NorESM_BSO_gsn', 'gsnvoltransp_BSO_in']

coeffs = [1, 1e-6, 1, 1, 1]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    voltrin = np.append(voltrin,val1)
    voltrin = np.append(voltrin,val2)
    
        
ctln = ['ctlbarents_heattotal', 'barht_c[0]', 'BSOrefheat', 'ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO']
gspn = ['gspbarents_heattotal', 'barht_gsp[0]', 'BSOgspheat', 'ht_NorESM_BSO_gsp', 'gspheattransp_BSO']
gsnn = ['gsnbarents_heattotal', 'barht_gsm[0]', 'BSOgsnheat', 'ht_NorESM_BSO_gsn', 'gsnheattransp_BSO']
    
coeffs = [1, 1, 1, 1, 1]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    heattr = np.append(heattr,val1)
    heattr = np.append(heattr,val2)

    
ctln = ['ctlbarents_heatinflow', 'barht_c[1]', 'BSOrefheat_in', 'inflow_ht_NorESM_BSO_ctrl', 'ctlheattransp_BSO_in']
gspn = ['gspbarents_heatinflow', 'barht_gsp[1]', 'BSOgspheat_in', 'inflow_ht_NorESM_BSO_gsp', 'gspheattransp_BSO_in']
gsnn = ['gsnbarents_heatinflow', 'barht_gsm[1]', 'BSOgsnheat_in', 'inflow_ht_NorESM_BSO_gsn', 'gsnheattransp_BSO_in']
    
coeffs = [1, 1, 1, 1, 1]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    heattrin = np.append(heattrin,val1)
    heattrin = np.append(heattrin,val2)
    
    
ctln = ['ctlxice_barents', 'SIextBK_c', 'refice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_ctrl', 'ctliext_BK']
gspn = ['gspxice_barents', 'SIextBK_gsp', 'gspice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsp', 'gspiext_BK']
gsnn = ['gsnxice_barents', 'SIextBK_gsm', 'gsnice_extent_BSKS', 'ice_extent_NorESM_BarentsKara_gsn', 'gsniext_BK']
    
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    seaiceextBS = np.append(seaiceextBS,val1)
    seaiceextBS = np.append(seaiceextBS,val2)    

    
ctln = ['ctlxice', 'SIext_c', 'refice_extent_NH', 'ice_extent_NorESM_NH_ctrl', 'ctliext']
gspn = ['gspxice', 'SIext_gsp', 'gspice_extent_NH', 'ice_extent_NorESM_NH_gsp', 'gspiext']
gsnn = ['gsnxice', 'SIext_gsm', 'gsnice_extent_NH', 'ice_extent_NorESM_NH_gsn', 'gsniext']
    
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    seaiceextNH = np.append(seaiceextNH,val1)
    seaiceextNH = np.append(seaiceextNH,val2)    

    
ctln = ['ctlvice_barents', 'SIvolBK_c', 'refice_volume_BSKS', 'ice_volume_NorESM_BarentsKara_ctrl', 'ctlivol_BK']
gspn = ['gspvice_barents', 'SIvolBK_gsp', 'gspice_volume_BSKS', 'ice_volume_NorESM_BarentsKara_gsp', 'gspivol_BK']
gsnn = ['gsnvice_barents', 'SIvolBK_gsm', 'gsnice_volume_BSKS', 'ice_volume_NorESM_BarentsKara_gsn', 'gsnivol_BK']
    
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    seaicevolBS = np.append(seaicevolBS,val1)
    seaicevolBS = np.append(seaicevolBS,val2)  
    
    
ctln = ['ctlvice', 'SIvol_c', 'refice_volume_NH', 'ice_volume_NorESM_NH_ctrl', 'ctlivol']
gspn = ['gspvice', 'SIvol_gsp', 'gspice_volume_NH', 'ice_volume_NorESM_NH_gsp', 'gspivol']
gsnn = ['gsnvice', 'SIvol_gsm', 'gsnice_volume_NH', 'ice_volume_NorESM_NH_gsn', 'gsnivol']
    
coeffs = [1e-9, 1e-9, 1e-9, 1e-9, 1e-9]
for ind,mdl in enumerate(modelnames):
    dnm = 'ds'+np.str(ind)+'.'+ctln[ind]+'.groupby(\'time.year\').mean()'
    dnm2 = 'ds'+np.str(ind)+'.'+gspn[ind]+'.groupby(\'time.year\').mean()'
    dnm3 = 'ds'+np.str(ind)+'.'+gsnn[ind]+'.groupby(\'time.year\').mean()'
    val1 = (np.copy(eval(dnm2)-eval(dnm))*coeffs[ind])
    val2 = (np.copy(eval(dnm3)-eval(dnm))*coeffs[ind])
    seaicevolNH = np.append(seaicevolNH,val1)
    seaicevolNH = np.append(seaicevolNH,val2)      
    
#    dnm = mdl+varnames[0]
#    print dnm
#    data.update({'time': time})
#    data.update({'volume': val1})
#    data.update({'volume': val2})
    
data = {}   
data.update({'time': time})
data.update({'volume': voltr})
data.update({'volumein': voltrin})
data.update({'heat': heattr})
data.update({'heatin': heattrin})
data.update({'seaiceextBS': seaiceextBS})
data.update({'seaiceextNH': seaiceextNH})
data.update({'seaicevolBS': seaicevolBS})
data.update({'seaicevolNH': seaicevolNH})
data.update({'direction': direction})
data.update({'models': models})
data.update({'unit': np.linspace(1,290,num=290)})
    
df = pd.DataFrame(data=data)    
df.to_csv('models_BSO_GSexps.csv')

# %%
plt.figure()
#plt.plot(df.volume[df['models']=='ITU' and df['direction']==1])
plt.plot(df.time[((df["models"]=='ITU') & (df["direction"]==-1))], 
         df.volume[((df["models"]=='ITU') & (df["direction"]==1))],'b-')
plt.plot(df.time[((df["models"]=='ITU') & (df["direction"]==-1))], 
         df.volume[((df["models"]=='ITU') & (df["direction"]==-1))],'b--')

# %%
df

# %%
ds4.ctliext
